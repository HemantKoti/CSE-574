# %% [markdown]
# # CSE474/574 - Programming Assignment 2

# %% [markdown]
# ## Part 1 - Sentiment Analysis
#
# In the code provided below, you need to add code wherever specified by `TODO:`.
#
# > You will be using a Python collection class - `Counter` to maintain the word counts.
#
# > See https://docs.python.org/2/library/collections.html for more details.

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import time
import os
# %matplotlib inline

# %%
# Load the Drive helper and mount
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# os.listdir('drive/My Drive/pa2')
# Out:
# ['.ipynb_checkpoints',
#  '__MACOSX',
#  'labels.txt',
#  'assignment2.pdf',
#  'vocab.txt',
#  'reviews.txt',
#  'AI_quick_draw.pickle',
#  'PA2-Part2.ipynb',
#  'data1.hdf5',
#  'PA2-Part1.ipynb']

# %%
# os.chdir('drive/My Drive/pa2')

# %%
# read data files 
g = open('reviews.txt','r') # What we know!
reviews_all = list(map(lambda x:x[:-1],g.readlines()))
g.close()
g = open('labels.txt','r') # What we WANT to know!
sentiments_all = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# load vocabulary
g = open('vocab.txt','r')
vocab = [s.strip() for s in g.readlines()]

# %% [markdown]
# The data is a set of 25000 movie reviews, along with a `POSITIVE` or `NEGATIVE` sentiment label assigned to the review.

# %%
# Check out sample reviews
print('A {} review:'.format(sentiments_all[0]))
print(reviews_all[0])
print('\nA {} review:'.format(sentiments_all[1]))
print(reviews_all[1])
# Out:
# A POSITIVE review:
# bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t
#
# A NEGATIVE review:
# story of a man who has unnatural feelings for a pig . starts out with a opening scene that is a terrific example of absurd comedy . a formal orchestra audience is turned into an insane  violent mob by the crazy chantings of it  s singers . unfortunately it stays absurd the whole time with no general narrative eventually making it just too off putting . even those from the era should be turned off . the cryptic dialogue would make shakespeare seem easy to a third grader . on a technical level it  s better than you might think with some good cinematography by future great vilmos zsigmond . future stars sally kirkland and frederic forrest can be seen briefly .

# %%
# split into training and test data
reviews_train,reviews_test = reviews_all[0:24000],reviews_all[24000:]
sentiments_train,sentiments_test = sentiments_all[0:24000],sentiments_all[24000:]

# %%
# maintain Counter objects to store positive, negative and total counts for
# all the words present in the positive, negative and total reviews.
positive_word_count = Counter()
negative_word_count = Counter()
total_counts = Counter()
# TODO: Loop over all the words in the vocabulary
# and increment the counts in the appropriate counter objects
# based on the training data
for i in range(len(sentiments_all)):
    word_list = reviews_all[i].split(' ')
    if sentiments_all[i] == 'POSITIVE':
        positive_word_count += Counter(word_list)
    elif sentiments_all[i] == 'NEGATIVE':
        negative_word_count += Counter(word_list)
    total_counts += Counter(word_list)

# %%
# maintain a Counter object to store positive to negative ratios 
pos_neg_ratios = Counter()

# Calculate the ratios of positive and negative uses of the most common words
# Consider words to be "common" if they've been used at least 100 times
for term,cnt in list(total_counts.most_common()):
    if(cnt > 100):
    
        # TODO: Code for calculating the ratios (remove the next line)
        if negative_word_count[term] and positive_word_count[term]:
            pos_neg_ratios[term] = positive_word_count[term] / negative_word_count[term]
        elif positive_word_count[term]:
            pos_neg_ratios[term] = positive_word_count[term]
        elif negative_word_count[term]:
            pos_neg_ratios[term] = negative_word_count[term]

# %%
# Delete which are not vocubulary words
non_vocab = [x for x in pos_neg_ratios if x not in vocab]
for item in non_vocab:
  del pos_neg_ratios[item]

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0608058070004713
# Pos-to-neg ratio for 'amazing' = 4.038167938931298
# Pos-to-neg ratio for 'terrible' = 0.17757009345794392

# %%
# take a log of the ratio
for word,ratio in pos_neg_ratios.most_common():
    pos_neg_ratios[word] = np.log(ratio)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902881460535952
# Pos-to-neg ratio for 'amazing' = 1.3957911086571477
# Pos-to-neg ratio for 'terrible' = -1.7283898552954657

# %%
# visualize the distribution of the log-ratio scores
scores = np.array(list(pos_neg_ratios.values()))
vocab_selected = list(pos_neg_ratios.keys())

h = plt.hist(scores,bins=20)

# %%
b = plt.boxplot(scores,vert=False)

# %%
q90, q85, q80, q75, q25, q20, q19,q17, q15, q10 = np.percentile(scores, [90, 85, 80, 75, 25, 20, 19, 17.5, 15, 10])

# %%
iqr = q75 - q25

# %%
iqr
# Out:
# 0.6437504710952111

# %%
print(q90, q85, q80, q75, q25, q20, q19,q17, q15, q10)
# Out:
# 0.750434885820101 0.5990153583942428 0.5016504644317252 0.4185804759711841 -0.22516999512402702 -0.31398509523942253 -0.3342155946218214 -0.3686072599716792 -0.43944423277571365 -0.621858337543099

# %% [markdown]
# The above histogram should give you an idea about the distribution of the scores.
#
# Notice how the scores are distributed around 0. A word with score 0 can be considered as `neutral`.

# %%
# Print few words with neutral score
for ind in np.where(scores == 0)[0][0:10]:
    print(vocab_selected[ind])
# Out:
# agree
# batman
# church
# opera
# direct
# ms
# sight
# board
# scale
# account

# %% [markdown]
# **APPROACH 1** Implement a simple non-machine learning that only uses the log-ratios to determine if a review is positive or negative. This function will be applied to the test data to calculate the accuracy of the model.
#
# _See the assignment document for hints._

# %%
def nonml_classifier(review,pos_neg_ratios):
    '''
    Function that determines the sentiment for a given review.
    
    Inputs:
      review - A text containing a movie review
      pos_neg_ratios - A Counter object containing frequent words
                       and corresponding log positive-negative ratio
    Return:
      sentiment - 'NEGATIVE' or 'POSITIVE'
    '''
    # TODO: Implement the algorithm here. Change the next line.
    sum_all = 0
    for item in review.split():
        if pos_neg_ratios[item] > q80:
            sum_all +=1
        elif pos_neg_ratios[item] < q10:
            sum_all -=1
    if sum_all >= 0:
        return 'POSITIVE'
    else:
        return 'NEGATIVE'

# %%
predictions_test = []
for r in reviews_test:
    l = nonml_classifier(r,pos_neg_ratios)
    predictions_test.append(l)

# calculate accuracy
correct = 0
for l,p in zip(sentiments_test,predictions_test):
    if l == p:
        correct = correct + 1
print('Accuracy of the model = {}'.format(correct/len(sentiments_test)))
# Out:
# Accuracy of the model = 0.771

# %%
ignore_words = [word for word,ratio in pos_neg_ratios.items() if ratio>q10 and ratio<q80 ]

# %%
for i in ignore_words:
  print(i)
# Out:
# the
# and
# a
# of
# to
# is
# br
# it
# in
# i
# this
# that
# s
# was
# as
# for
# with
# movie
# but
# film
# you
# on
# t
# not
# he
# are
# his
# have
# be
# one
# all
# at
# they
# by
# an
# who
# so
# from
# like
# there
# her
# or
# just
# about
# out
# if
# has
# what
# some
# good
# can
# more
# she
# when
# very
# up
# time
# no
# even
# my
# would
# which
# story
# only
# really
# see
# their
# had
# we
# were
# me
# well
# than
# much
# get
# been
# people
# will
# do
# other
# also
# into
# first
# because
# how
# him
# don
# most
# made
# its
# then
# make
# way
# them
# could
# too
# movies
# any
# after
# think
# characters
# character
# watch
# two
# films
# seen
# many
# being
# plot
# acting
# never
# little
# where
# over
# did
# show
# know
# off
# ever
# man
# does
# here
# better
# your
# end
# still
# these
# say
# scene
# while
# scenes
# go
# ve
# such
# something
# should
# m
# back
# through
# real
# those
# watching
# now
# though
# doesn
# thing
# old
# years
# re
# actors
# director
# work
# another
# before
# didn
# new
# funny
# actually
# makes
# look
# find
# going
# few
# same
# part
# again
# every
# lot
# cast
# us
# quite
# down
# want
# things
# pretty
# seems
# around
# horror
# got
# however
# fact
# take
# big
# enough
# long
# thought
# between
# may
# give
# original
# action
# own
# right
# without
# must
# comedy
# times
# point
# gets
# come
# role
# isn
# saw
# almost
# interesting
# least
# done
# whole
# d
# bit
# music
# guy
# far
# making
# feel
# anything
# last
# might
# since
# ll
# girl
# probably
# am
# woman
# kind
# tv
# away
# yet
# day
# rather
# sure
# hard
# anyone
# played
# found
# having
# although
# especially
# our
# course
# believe
# screen
# comes
# looking
# trying
# set
# goes
# book
# looks
# place
# actor
# put
# year
# ending
# dvd
# maybe
# let
# someone
# once
# sense
# everything
# wasn
# three
# worth
# main
# together
# play
# watched
# american
# everyone
# plays
# john
# effects
# later
# audience
# said
# takes
# house
# seem
# night
# high
# himself
# version
# wife
# during
# left
# special
# seeing
# half
# star
# shot
# idea
# black
# nice
# less
# else
# mind
# simply
# read
# second
# fan
# men
# death
# hollywood
# help
# completely
# used
# home
# dead
# line
# short
# either
# given
# top
# kids
# budget
# try
# wrong
# women
# need
# use
# rest
# friends
# production
# full
# camera
# until
# along
# truly
# video
# couple
# tell
# next
# remember
# start
# stars
# perhaps
# sex
# won
# came
# recommend
# moments
# school
# episode
# small
# face
# understand
# playing
# getting
# written
# early
# name
# doing
# often
# style
# keep
# others
# person
# itself
# boy
# lines
# lost
# live
# become
# dialogue
# head
# piece
# finally
# case
# yes
# felt
# mother
# liked
# children
# title
# cinema
# white
# absolutely
# picture
# against
# sort
# certainly
# went
# entire
# killer
# problem
# mr
# hope
# evil
# entertaining
# friend
# overall
# called
# based
# fans
# several
# drama
# beginning
# direction
# care
# already
# dark
# becomes
# laugh
# example
# under
# despite
# seemed
# throughout
# turn
# son
# wanted
# michael
# history
# final
# child
# sound
# lead
# humor
# totally
# writing
# guys
# quality
# close
# art
# wants
# game
# behind
# town
# side
# tries
# days
# past
# viewer
# able
# flick
# hand
# genre
# turns
# act
# kill
# car
# soon
# starts
# run
# actress
# sometimes
# gave
# eyes
# b
# late
# girls
# etc
# god
# directed
# kid
# parts
# blood
# self
# themselves
# stories
# thinking
# expect
# stuff
# obviously
# voice
# writer
# fight
# myself
# feeling
# daughter
# slow
# except
# matter
# type
# anyway
# roles
# moment
# killed
# heard
# says
# leave
# brother
# took
# cannot
# police
# violence
# hit
# stop
# happens
# known
# particularly
# involved
# happened
# chance
# extremely
# james
# obvious
# murder
# told
# living
# coming
# alone
# experience
# hero
# including
# happen
# wonder
# cut
# group
# complete
# ago
# interest
# score
# husband
# hell
# song
# career
# number
# possible
# sad
# exactly
# shown
# king
# running
# yourself
# serious
# scary
# reality
# taken
# whose
# released
# cinematography
# english
# ends
# hours
# usually
# opening
# jokes
# light
# hilarious
# across
# cool
# body
# somewhat
# usual
# happy
# view
# level
# started
# change
# opinion
# wish
# novel
# middle
# talking
# taking
# documentary
# ones
# robert
# order
# shots
# power
# female
# huge
# room
# mostly
# country
# five
# talent
# important
# rating
# modern
# earth
# strange
# major
# word
# turned
# call
# single
# disappointed
# events
# four
# due
# songs
# basically
# attention
# television
# comic
# knows
# non
# clearly
# knew
# british
# fast
# thriller
# class
# easily
# problems
# aren
# words
# miss
# entertainment
# local
# sequence
# rock
# bring
# beyond
# george
# straight
# o
# upon
# whether
# sets
# similar
# review
# eye
# falls
# mystery
# lady
# richard
# talk
# appears
# needs
# giving
# within
# message
# theater
# ten
# near
# team
# above
# sequel
# red
# sister
# theme
# stand
# nearly
# lee
# points
# mention
# add
# feels
# herself
# haven
# release
# ways
# storyline
# surprised
# using
# named
# lots
# working
# die
# actual
# feature
# minute
# hate
# stay
# follow
# viewers
# clear
# tom
# elements
# comments
# typical
# editing
# showing
# fall
# dialog
# check
# peter
# period
# form
# certain
# general
# filmed
# buy
# soundtrack
# parents
# means
# material
# figure
# doubt
# somehow
# crime
# space
# gone
# disney
# kept
# leads
# th
# dance
# suspense
# third
# brought
# imagine
# hear
# whatever
# particular
# de
# america
# sequences
# move
# indeed
# eventually
# average
# learn
# wait
# forget
# reviews
# deal
# note
# japanese
# surprise
# stage
# sexual
# sit
# possibly
# subject
# decided
# expected
# truth
# imdb
# dr
# street
# free
# became
# screenplay
# difficult
# romance
# killing
# baby
# joe
# dog
# nor
# hot
# reading
# question
# needed
# leaves
# begin
# directors
# credits
# shame
# otherwise
# situation
# meet
# dramatic
# male
# open
# earlier
# writers
# weird
# dream
# forced
# fi
# acted
# sci
# crazy
# laughs
# older
# realize
# comment
# footage
# forward
# interested
# ask
# whom
# plus
# sounds
# mark
# directing
# keeps
# development
# features
# air
# quickly
# creepy
# box
# towards
# girlfriend
# worked
# cheesy
# setting
# effect
# plenty
# hands
# bill
# result
# previous
# fire
# incredibly
# rate
# business
# doctor
# casting
# return
# apart
# christmas
# leading
# e
# admit
# appear
# cop
# background
# boys
# ben
# meant
# telling
# battle
# hardly
# break
# create
# potential
# secret
# pay
# political
# gay
# fighting
# twist
# various
# co
# portrayed
# inside
# villain
# western
# outside
# reasons
# ideas
# front
# missing
# deserves
# married
# expecting
# rich
# fairly
# talented
# list
# scott
# attempts
# manages
# remake
# odd
# social
# cute
# spoilers
# copy
# c
# further
# wrote
# sadly
# agree
# cold
# crew
# office
# mary
# filmmakers
# following
# missed
# public
# mentioned
# gun
# pure
# ended
# large
# produced
# caught
# revenge
# members
# pace
# la
# filled
# popular
# party
# waiting
# science
# water
# cat
# decides
# cartoon
# hold
# considering
# spirit
# tension
# created
# slightly
# uses
# fear
# convincing
# compared
# familiar
# suddenly
# escape
# island
# cause
# intelligent
# clever
# state
# entirely
# dancing
# language
# credit
# choice
# kills
# band
# laughing
# italian
# value
# violent
# visual
# successful
# speak
# trouble
# ultimately
# basic
# concept
# singing
# store
# positive
# studio
# german
# biggest
# company
# exciting
# force
# runs
# consider
# died
# control
# depth
# recent
# walk
# former
# amusing
# common
# law
# spend
# focus
# rated
# books
# hair
# younger
# planet
# super
# tone
# mad
# bizarre
# respect
# follows
# college
# amount
# culture
# van
# impossible
# prison
# trip
# heavy
# project
# dad
# win
# chemistry
# conclusion
# showed
# fit
# sick
# situations
# starring
# accent
# disturbing
# u
# considered
# ghost
# changed
# steve
# cult
# post
# somewhere
# decide
# honest
# leaving
# questions
# anti
# shooting
# tough
# longer
# audiences
# fiction
# west
# aside
# meaning
# computer
# ex
# generally
# literally
# values
# likes
# alive
# involving
# camp
# immediately
# military
# detective
# london
# week
# bought
# normal
# sam
# aspect
# fair
# pictures
# ability
# adaptation
# army
# pick
# nobody
# sitting
# appearance
# explain
# glad
# motion
# attack
# standard
# drive
# appeal
# catch
# personally
# sexy
# humour
# added
# thank
# comedies
# walking
# silent
# purpose
# remains
# chase
# loud
# naked
# taste
# thinks
# producer
# road
# date
# terms
# wow
# equally
# mood
# club
# wild
# door
# blue
# drawn
# batman
# g
# key
# fully
# managed
# narrative
# pieces
# government
# likely
# plan
# climax
# soldiers
# gang
# chris
# pass
# soul
# issues
# justice
# surely
# boss
# constantly
# victim
# thus
# costumes
# presented
# christopher
# slowly
# cinematic
# finish
# central
# hey
# train
# contains
# everybody
# presence
# besides
# places
# manner
# details
# spoiler
# thrown
# r
# historical
# charles
# animals
# photography
# scenery
# indian
# smart
# jones
# church
# speaking
# mysterious
# impression
# allen
# expectations
# green
# developed
# drug
# numbers
# exception
# ahead
# minor
# double
# woods
# track
# festival
# critics
# boyfriend
# aspects
# lover
# million
# hotel
# emotion
# opera
# brief
# building
# acts
# opportunity
# serial
# mainly
# bruce
# filming
# support
# student
# forever
# element
# names
# held
# intended
# twice
# dies
# j
# changes
# bar
# born
# shock
# bed
# six
# happening
# likable
# falling
# lived
# hurt
# puts
# tired
# jerry
# giant
# spot
# image
# pain
# st
# offer
# confused
# trailer
# suggest
# victims
# ray
# adults
# include
# difference
# al
# billy
# summer
# step
# followed
# event
# hasn
# sub
# appeared
# park
# system
# putting
# actresses
# mix
# laughed
# notice
# murders
# martin
# mom
# content
# direct
# moral
# race
# rape
# americans
# wall
# flaws
# land
# worthy
# creative
# latter
# l
# students
# lighting
# agent
# answer
# merely
# wondering
# proves
# ii
# seven
# wise
# flying
# hospital
# damn
# flicks
# stone
# imagination
# forgotten
# x
# standards
# beat
# ground
# attractive
# count
# absolute
# negative
# extreme
# ms
# stuck
# lord
# becoming
# seemingly
# reminded
# folks
# ship
# addition
# queen
# soldier
# affair
# fell
# faces
# lose
# industry
# williams
# turning
# afraid
# detail
# collection
# design
# pull
# hidden
# nasty
# animal
# fashion
# teen
# quick
# artistic
# shocking
# shouldn
# personality
# roll
# lets
# location
# area
# chinese
# length
# ready
# states
# angry
# information
# professional
# therefore
# filmmaker
# anymore
# food
# wars
# mouth
# news
# listen
# jason
# led
# picked
# describe
# deliver
# clothes
# onto
# asks
# grace
# martial
# struggle
# intelligence
# member
# carry
# captain
# wearing
# stephen
# criminal
# ed
# cross
# teenage
# allowed
# sleep
# compare
# drugs
# necessary
# desperate
# helped
# machine
# plane
# sight
# witch
# trust
# phone
# station
# heaven
# willing
# includes
# mid
# began
# theatre
# humans
# nightmare
# heroes
# build
# accident
# commentary
# energy
# pop
# realized
# powers
# suicide
# extra
# comedic
# rarely
# taylor
# dying
# independent
# teacher
# devil
# introduced
# engaging
# johnny
# actions
# suit
# warning
# anybody
# religious
# arts
# mental
# apparent
# tim
# superman
# p
# allow
# physical
# returns
# continue
# memory
# keaton
# technical
# provide
# wedding
# vision
# normally
# scared
# anywhere
# media
# ford
# limited
# adam
# fred
# finished
# bloody
# russian
# process
# intriguing
# kate
# suspect
# cops
# pilot
# exist
# jump
# accept
# legend
# player
# twenty
# hitler
# horse
# search
# wanting
# faith
# soft
# shakespeare
# according
# pacing
# moon
# gold
# cage
# price
# asked
# ladies
# ill
# bits
# dressed
# nick
# drunk
# dangerous
# constant
# deserved
# lies
# n
# field
# originally
# ball
# community
# heroine
# heads
# higher
# instance
# kevin
# freddy
# candy
# issue
# mixed
# met
# capture
# unknown
# gotten
# toward
# fights
# fail
# plots
# soap
# knowledge
# creating
# record
# guns
# starting
# european
# humanity
# ice
# whilst
# mike
# floor
# spanish
# wide
# hadn
# officer
# cable
# judge
# cars
# broken
# loose
# villains
# eating
# lynch
# partner
# featuring
# aware
# saving
# responsible
# mine
# treated
# kinda
# eat
# results
# cuts
# wind
# pulled
# sign
# author
# singer
# bright
# hopes
# conflict
# vs
# hits
# noticed
# included
# manage
# forces
# months
# wood
# loss
# gary
# sing
# private
# kong
# fate
# whenever
# driving
# blonde
# numerous
# concerned
# talents
# ordinary
# scream
# bigger
# dated
# skills
# naturally
# finale
# reviewers
# ass
# v
# discover
# international
# regular
# ups
# opposite
# morning
# bob
# prove
# kick
# bank
# sea
# portray
# loses
# shop
# anthony
# locations
# humorous
# grant
# mission
# blind
# luck
# curious
# edited
# gags
# sean
# satire
# behavior
# survive
# miles
# murdered
# calls
# mrs
# context
# core
# existence
# foot
# opens
# cameo
# breaks
# jennifer
# connection
# lucky
# corny
# buddy
# current
# essentially
# window
# revealed
# lesson
# occasionally
# frankly
# harris
# decade
# dimensional
# national
# village
# african
# thomas
# learned
# anne
# efforts
# boat
# program
# grown
# visuals
# develop
# formula
# genuinely
# references
# board
# study
# grew
# desert
# lake
# bear
# suffering
# comparison
# favor
# overly
# reaction
# proved
# meanwhile
# speed
# president
# standing
# robin
# psycho
# sudden
# awkward
# leader
# steal
# parody
# reach
# unable
# types
# sheer
# evening
# killers
# frame
# passed
# travel
# stereotypes
# technology
# gordon
# bet
# site
# round
# sheriff
# halloween
# hill
# delivered
# clean
# parker
# laughter
# relief
# insane
# model
# executed
# pair
# steven
# flashbacks
# woody
# fault
# decision
# reviewer
# hunter
# commercial
# graphic
# ran
# code
# majority
# protagonist
# native
# religion
# entertained
# caused
# foreign
# built
# asian
# vehicle
# feet
# test
# wayne
# cash
# rise
# obsessed
# treatment
# levels
# tape
# practically
# wit
# range
# gory
# classics
# aged
# ancient
# described
# seat
# chosen
# product
# center
# sell
# fly
# exploitation
# rescue
# hearing
# breaking
# send
# angel
# alex
# excited
# dry
# stopped
# chief
# uk
# pity
# fame
# proper
# theaters
# produce
# theatrical
# cares
# asking
# capable
# believes
# w
# largely
# safe
# choose
# moore
# canadian
# crowd
# marry
# recall
# depressing
# extras
# cant
# dubbed
# appealing
# matt
# matters
# facts
# involves
# ryan
# correct
# evidence
# costume
# vote
# anderson
# hunt
# research
# strongly
# mask
# claim
# teenager
# heck
# football
# losing
# excitement
# saturday
# cost
# talks
# eight
# promise
# destroy
# thoughts
# fool
# scare
# factor
# circumstances
# naive
# market
# training
# voices
# bodies
# haunted
# teenagers
# universal
# robot
# convinced
# bringing
# united
# hanging
# creatures
# max
# welcome
# danger
# hopefully
# lower
# spoil
# virtually
# tiny
# fairy
# till
# north
# relatively
# reporter
# mini
# walks
# murphy
# skin
# covered
# hat
# africa
# drag
# category
# unlikely
# lawyer
# fare
# witness
# handled
# target
# viewed
# cutting
# hide
# scale
# texas
# unfortunate
# initial
# shocked
# remain
# service
# holding
# kim
# believed
# professor
# politics
# weekend
# presents
# movement
# section
# qualities
# closer
# angles
# structure
# australian
# liners
# source
# designed
# drop
# claims
# cartoons
# deaths
# display
# previously
# edward
# degree
# clark
# faced
# plans
# caine
# repeated
# focused
# ruin
# enemy
# roger
# propaganda
# weeks
# serves
# treasure
# blow
# speaks
# chose
# related
# supernatural
# highlight
# prime
# pacino
# deadly
# latest
# veteran
# routine
# granted
# erotic
# suffers
# crash
# wilson
# harsh
# dollars
# speech
# print
# mistakes
# invisible
# accidentally
# alice
# sympathy
# teens
# twisted
# dogs
# friday
# nude
# guilty
# draw
# combined
# struggling
# terror
# matrix
# convince
# path
# dozen
# universe
# enter
# mountain
# birth
# gas
# committed
# irish
# technically
# recognize
# sword
# driver
# changing
# aka
# sun
# lugosi
# sarah
# directly
# darkness
# false
# occasional
# explains
# department
# prior
# abuse
# narration
# offered
# experienced
# massive
# vietnam
# theory
# featured
# surface
# beach
# johnson
# reputation
# crying
# passing
# kinds
# everywhere
# sorts
# un
# multiple
# statement
# forth
# required
# network
# nazi
# bbc
# reveal
# stolen
# regret
# california
# metal
# conversation
# exact
# express
# rachel
# scares
# trapped
# jon
# spends
# belief
# fictional
# hired
# freeman
# dean
# jungle
# placed
# julia
# san
# rule
# insight
# abandoned
# blockbuster
# worthwhile
# listening
# bus
# afternoon
# crude
# beast
# susan
# lisa
# lifetime
# account
# wear
# jobs
# dragon
# angle
# minds
# imagery
# foster
# cultural
# blown
# paying
# buying
# rights
# larry
# quest
# scenario
# rolling
# delivery
# starred
# mexican
# amazed
# productions
# ron
# artists
# status
# views
# shadow
# thankfully
# significant
# stayed
# dress
# lights
# teeth
# interview
# mere
# table
# examples
# device
# indie
# cruel
# hip
# ghosts
# necessarily
# heavily
# skill
# suffer
# sleeping
# achieve
# spite
# campy
# understood
# murderer
# seek
# format
# desperately
# forgot
# beloved
# destroyed
# summary
# closing
# hardy
# flight
# decades
# pregnant
# warner
# racist
# facial
# wing
# ignore
# breath
# slapstick
# intellectual
# flashback
# fourth
# calling
# cell
# drinking
# critical
# elizabeth
# learning
# expert
# arms
# description
# buck
# prefer
# encounter
# tree
# task
# settings
# regarding
# criminals
# underground
# amazingly
# ain
# sandler
# screening
# funnier
# storytelling
# punch
# base
# michelle
# praise
# jail
# notorious
# entertain
# choices
# prepared
# comical
# extent
# convey
# titles
# kiss
# expression
# trick
# spoof
# east
# experiment
# raised
# lane
# jessica
# toy
# bollywood
# graphics
# miller
# inspiration
# purely
# picks
# headed
# basis
# via
# spoken
# mirror
# shut
# introduction
# novels
# weapons
# charge
# notable
# properly
# term
# handle
# lie
# locked
# throws
# join
# maker
# serve
# guard
# strangely
# burt
# reference
# caring
# causes
# sitcom
# wears
# ratings
# cooper
# regard
# laura
# adding
# pet
# fallen
# challenge
# carrying
# lesser
# protect
# southern
# established
# nonetheless
# jewish
# amongst
# usa
# sleazy
# wins
# westerns
# raise
# confusion
# attempting
# cases
# remote
# carried
# gruesome
# escapes
# reed
# sinister
# inspector
# obsession
# risk
# mass
# replaced
# sold
# clips
# ironic
# hood
# needless
# hole
# minded
# enjoying
# per
# successfully
# busy
# nine
# flow
# exists
# mansion
# carpenter
# angels
# goofy
# legs
# oddly
# mentally
# jumps
# presentation
# attacked
# laid
# horrific
# comedian
# shape
# vacation
# shower
# fortunately
# em
# topic
# jay
# upper
# interviews
# text
# served
# grey
# stops
# attacks
# remind
# mob
# thrilling
# sin
# frequently
# bridge
# tongue
# chair
# glass
# fish
# flawed
# suspects
# contain
# opened
# baker
# hence
# pitch
# stranger
# riding
# internet
# drives
# rochester
# torn
# dinner
# franchise
# spielberg
# cynical
# upset
# revolves
# tour
# wishes
# racism
# storm
# thousands
# wealthy
# credible
# pool
# corner
# fbi
# lessons
# advantage
# catholic
# crisis
# broke
# burton
# pack
# spin
# controversial
# happily
# nelson
# snow
# streisand
# pride
# physically
# medical
# contact
# guessing
# alike
# hundreds
# succeed
# bag
# suffered
# dislike
# perform
# card
# performers
# technique
# enjoyment
# chaplin
# hundred
# flash
# millions
# neat
# whereas
# separate
# tied
# uncomfortable
# month
# assistant
# hint
# infamous
# drink
# weapon
# virgin
# irony
# holiday
# searching
# scripts
# cube
# curse
# cousin
# connected
# glory
# host
# letting
# plague
# protagonists
# cameos
# ad
# steps
# zone
# entry
# tune
# thousand
# quote
# meaningful
# suggests
# horses
# chasing
# nd
# massacre
# vincent
# arnold
# hamlet
# stealing
# accepted
# noted
# stretch
# burning
# hiding
# fortune
# split
# stan
# strip
# guts
# gain
# saves
# hunting
# basement
# neighborhood
# hang
# attraction
# equal
# spots
# condition
# chases
# chuck
# oil
# belongs
# dialogs
# catherine
# destruction
# repeat
# worry
# pro
# dig
# roberts
# factory
# shoots
# pat
# object
# dorothy
# walken
# thirty
# appearing
# neck
# homeless
# concerns
# closely
# competent
# ultra
# flaw
# scientists
# trade
# segments
# hanks
# multi
# eva
# wake
# encounters
# library
# expensive
# knock
# rush
# virus
# elsewhere
# loser
# letter
# crimes
# checking
# sends
# silver
# neighbor
# canada
# solve
# lloyd
# charisma
# bobby
# rushed
# rocks
# colour
# dragged
# beating
# dare
# goal
# teach
# weight
# hitting
# fitting
# spell
# slight
# doc
# birthday
# believing
# cusack
# briefly
# techniques
# magazine
# tea
# thumbs
# stunt
# videos
# attempted
# countless
# bride
# painting
# dawn
# heston
# sally
# brand
# kane
# sexually
# specific
# pointed
# iii
# mild
# godfather
# smoking
# reactions
# surrounding
# surrounded
# admittedly
# neil
# barry
# jerk
# grows
# revelation
# relevant
# comics
# homage
# corrupt
# fired
# poverty
# stronger
# eyed
# spike
# walls
# kicks
# chances
# guest
# tons
# shall
# stated
# executive
# row
# easier
# duke
# medium
# represents
# killings
# intention
# enters
# attached
# ian
# increasingly
# associated
# strike
# inevitable
# projects
# occurs
# dropped
# requires
# mafia
# messages
# korean
# university
# forgive
# resolution
# silence
# typically
# acceptable
# identify
# jesse
# luckily
# nights
# reynolds
# worker
# selling
# thrills
# hire
# creation
# strictly
# savage
# gotta
# estate
# heat
# jamie
# continued
# fifteen
# instantly
# struck
# cruise
# disease
# beings
# satan
# rex
# allowing
# ego
# commit
# partly
# handful
# spirited
# afterwards
# press
# kidnapped
# importantly
# evident
# digital
# pushed
# persona
# competition
# creators
# grandmother
# realise
# wondered
# talked
# ambitious
# arrested
# threatening
# photographed
# relative
# menacing
# buried
# returning
# aforementioned
# ho
# conspiracy
# doors
# citizen
# nurse
# size
# jumping
# diamond
# frustrated
# highlights
# spiritual
# wonders
# twin
# corpse
# jet
# listed
# mitchell
# regardless
# samurai
# curiosity
# planning
# characterization
# rap
# ticket
# string
# narrator
# fatal
# push
# admire
# trap
# lou
# spooky
# cup
# border
# beaten
# outrageous
# piano
# critic
# accused
# goldberg
# notes
# beer
# spoiled
# picking
# prevent
# territory
# mile
# francisco
# clues
# butt
# attracted
# cia
# indians
# blows
# revealing
# response
# logical
# opposed
# melodramatic
# watches
# farce
# mate
# chain
# souls
# root
# shortly
# turner
# ellen
# directorial
# pulling
# hatred
# cared
# liberal
# los
# precious
# suits
# installment
# subplot
# tall
# laurel
# shoes
# wes
# convoluted
# editor
# intrigued
# poster
# marks
# sole
# ignored
# aimed
# exaggerated
# titled
# warrior
# remaining
# conceived
# futuristic
# psychotic
# repeatedly
# mel
# restaurant
# notably
# ah
# tunes
# fancy
# parent
# failing
# drunken
# obscure
# smoke
# reasonably
# scientific
# superhero
# minimal
# distance
# dignity
# discussion
# argument
# outcome
# kitchen
# loosely
# rid
# scripted
# reduced
# misses
# shirt
# soviet
# wicked
# elaborate
# dont
# photographer
# glenn
# craven
# warren
# worried
# connect
# kenneth
# walker
# returned
# childish
# translation
# hysterical
# screams
# intent
# sticks
# slave
# eve
# exposed
# shadows
# stiller
# annie
# discovery
# absence
# contrary
# commercials
# areas
# folk
# wallace
# imagined
# birds
# thick
# tortured
# yesterday
# threat
# fever
# vicious
# donna
# reached
# arrive
# complain
# im
# stole
# broad
# improved
# ireland
# twelve
# rd
# concerning
# choreography
# matthew
# dancers
# extended
# incident
# farm
# karen
# movements
# bathroom
# existed
# drawing
# anyways
# occurred
# bite
# involvement
# bone
# web
# displays
# burned
# bare
# broadcast
# altman
# nazis
# ought
# cheek
# bird
# contained
# kapoor
# genres
# newspaper
# machines
# population
# craft
# antics
# audio
# resembles
# block
# ranks
# currently
# tommy
# nicholson
# leg
# pretend
# swedish
# cliff
# seventies
# harder
# neo
# receive
# investigate
# proceedings
# journalist
# altogether
# dynamic
# enjoys
# argue
# explosion
# bell
# adequate
# occur
# superficial
# website
# terry
# foul
# thrill
# popcorn
# thugs
# beats
# pulp
# hammer
# atlantis
# tame
# rage
# lawrence
# fighter
# selfish
# composed
# staged
# li
# suited
# leonard
# robots
# madonna
# escaped
# ease
# engaged
# dialogues
# innovative
# prostitute
# cats
# clothing
# juvenile
# conversations
# lit
# brains
# lol
# versus
# bullet
# offering
# murderous
# nearby
# staying
# staff
# orders
# philosophy
# garden
# lips
# combat
# buddies
# devoted
# grab
# centered
# bang
# disturbed
# producing
# react
# groups
# detailed
# mistaken
# liking
# banned
# cary
# hbo
# abilities
# blowing
# explosions
# possessed
# removed
# deliberately
# jeffrey
# spare
# masters
# ingredients
# defeat
# causing
# officers
# explaining
# distracting
# nightmares
# resemblance
# uneven
# careers
# relies
# bedroom
# undoubtedly
# harvey
# mickey
# subjects
# dating
# official
# succeeded
# crack
# classes
# catches
# furthermore
# explored
# goodness
# scheme
# signs
# duty
# primary
# focusing
# occasion
# funeral
# yellow
# politically
# aid
# discuss
# coffee
# passes
# punk
# backdrop
# wives
# sidekick
# smaller
# houses
# wont
# tracks
# financial
# models
# chaos
# trees
# props
# linda
# remarkably
# rick
# travels
# maggie
# spirits
# impress
# endings
# portion
# exotic
# measure
# primarily
# doomed
# amy
# notion
# settle
# decisions
# afford
# recorded
# hates
# consistently
# surviving
# beneath
# principal
# lyrics
# dutch
# ties
# mill
# fetched
# ocean
# method
# celebrity
# motives
# ya
# hints
# circle
# forty
# enemies
# enormous
# represent
# dozens
# performer
# communist
# frustration
# revolutionary
# mixture
# pan
# terrorist
# montage
# cheating
# et
# closet
# diane
# shirley
# grinch
# pig
# crush
# reaches
# tie
# fond
# akshay
# trailers
# judging
# user
# avoided
# buff
# developing
# rocket
# bold
# winds
# painted
# urge
# subtlety
# rank
# coach
# drops
# surfing
# survivors
# benefit
# simplistic
# eighties
# outfit
# advance
# angeles
# practice
# emphasis
# specifically
# disappear
# amanda
# blew
# authority
# oz
# cure
# cinematographer
# niro
# melting

# %% [markdown]
# **Approach 2** Implement a neural network for sentiment classification.
#
# > ### System Configuration
# This part requires you to use a computer with `tensorflow` library installed. More information is available here - https://www.tensorflow.org.
# `
# You are allowed to implement the project on your personal computers using `Python 3.4 or above. You will need `numpy` and `scipy` libraries. If you need to use departmental resources, you can use **metallica.cse.buffalo.edu**, which has `Python 3.4.3` and the required libraries installed.
#
# > Students attempting to use the `tensorflow` library have two options:
# 1. Install `tensorflow` on personal machines. Detailed installation information is here - https://www.tensorflow.org/. Note that, since `tensorflow` is a relatively new library, you might encounter installation issues depending on your OS and other library versions. We will not be providing any detailed support regarding `tensorflow` installation. If issues persist, we recommend using option 2.
# 2. Use **metallica.cse.buffalo.edu**. If you are registered into the class, you should have an account on that server. The server already has Python 3.4.3 and TensorFlow 0.12.1 installed. Please use /util/bin/python for Python 3.
# 3. To maintain a ssh connection for a long-running task on a remote machine, use tools like `screen`. For more information: https://linuxize.com/post/how-to-use-linux-screen/
# 4. For running jupyter-notebook over a remote machine find information on: https://fizzylogic.nl/2017/11/06/edit-jupyter-notebooks-over-ssh/

# %%
def create_input_vector(review,word2index):
    '''
    Function to count how many times each word is used in the given review,
    # and then store those counts at the appropriate indices inside x.
    '''
    vocab_size = len(word2index)
    x = np.zeros((1, vocab_size))
    for w in review.split():
        if w in word2index.keys():
            x[0][word2index[w]] += 1
    return x

# %%
def find_ignore_words(pos_neg_ratios):
    '''
    Function to identify words to ignore from the vocabulary
    '''
    ignore_words = [word for word,ratio in pos_neg_ratios.items() if ratio>q10 and ratio<q80 ]
    return ignore_words

# %%
# create a word2index mapping from word to an integer index
word2index = {}
ignore_words = find_ignore_words(pos_neg_ratios)
vocab_selected = list(set(vocab_selected).difference(set(ignore_words)))
for i,word in enumerate(vocab_selected):
    if word not in ignore_words:
        word2index[word] = i
vocab_size = len(word2index)

# %% [markdown]
# #### Generate .hdf5 files from the processed data
# Given that the data is moderately large sized, the `hdf5` file format provides a more efficient file representation for further processing. See [here](https://anaconda.org/anaconda/hdf5) for more details and installation instructions.

# %%
import h5py

# %%
# Run the script once to generate the file 
# delete the exiting 'data1.hdf5' file before running it again to avoid error 
labels_train = np.zeros((len(sentiments_train), 2), dtype=int)
labels_test = np.zeros((len(sentiments_test), 2), dtype=int)

with h5py.File('data1.hdf5', 'w') as hf:
    hf.create_dataset('data_train', (labels_train.shape[0], vocab_size), np.int16)
    hf.create_dataset('data_test', (labels_test.shape[0], vocab_size), np.int16)
    # create training data
    for i,(r,l) in enumerate(zip(reviews_train, sentiments_train)):
        hf["data_train"][i] = create_input_vector(r,word2index)
        # one-hot encoding
        if l == 'NEGATIVE':
            labels_train[i, 0] = 1
        else:
            labels_train[i, 1] = 1
    # create test data
    for i,(r,l) in enumerate(zip(reviews_test, sentiments_test)):
        hf["data_test"][i] = create_input_vector(r,word2index)
        # one-hot encoding
        if l == 'NEGATIVE':
            labels_test[i, 0] = 1
        else:
            labels_test[i, 1] = 1

# %%
# %tensorflow_version 1.x
import tensorflow as tf 
tf.compat.v1.random.set_random_seed(10)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# parameters of the network
learning_rate = 0.01
batch_size = 400
num_epochs = 50
n_input = vocab_size
n_classes = 2

# %% [markdown]
# For single hidden layer

# %%
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# Define weights and biases in Tensorflow according to the parameters set above
# Giving good accuracy with less neurons 
n_hidden_1 = 10 # 1st layer number of neurons
weights = {
    'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'out1': tf.Variable(tf.random_normal([n_hidden_1, n_classes]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out2': tf.Variable(tf.random_normal([n_classes]))
}

# %% [markdown]
# For two layers

# %%
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# Define weights and biases in Tensorflow according to the parameters set above
# Giving good accuracy with less neurons 
n_hidden_1 = 10 # 1st layer number of neurons
n_hidden_2 = 10
weights = {
    'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out1': tf.Variable(tf.random_normal([n_hidden_2, n_classes]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out2': tf.Variable(tf.random_normal([n_classes]))
}

# %% [markdown]
# For three layers

# %%
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# Define weights and biases in Tensorflow according to the parameters set above
# Giving good accuracy with less neurons 
n_hidden_1 = 10 # 1st layer number of neurons
n_hidden_2 = 10
n_hidden_3 = 5
weights = {
    'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out1': tf.Variable(tf.random_normal([n_hidden_3, n_classes]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out2': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def multilayer_perceptron(x):
    # define the layers of a single layer perceptron
    # need to add and delete according to layer which are been added or deleted
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2'])
    layer_3 = tf.add(tf.matmul(layer_2, weights['h3']), biases['b3'])
    out_layer = tf.nn.sigmoid(tf.matmul(layer_3, weights['out1']) + biases['out2'])
    return out_layer

# %%
logits = multilayer_perceptron(X)
# Define loss(softmax_cross_entropy_with_logits) and optimizer(AdamOptimizer)
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)
# Initializing the variables
init = tf.global_variables_initializer()

# %%
# for some macosx installations, conflicting copies of mpilib causes trouble with tensorflow.
# use the following two lines to resolve that issue
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
with tf.Session() as sess:
    start_time = time.time()
    sess.run(init)

    h = h5py.File('data1.hdf5', 'r')
    n1 = h.get('data_train') 
    n2 = h.get('data_test')

    # Training cycle
    total_batch_train = int(n1.shape[0] / batch_size)
    total_batch_test = int(n2.shape[0] / batch_size)

    for iter_num in range(num_epochs):
        # variables for train and test accuracies
        avg_acc_train = 0.
        avg_acc_test = 0.
        for i in range(total_batch_train):
            train_x = n1[(i) * batch_size: (i + 1) * batch_size, ...]
            train_y = labels_train[(i) * batch_size: (i + 1) * batch_size, :]

            _, c_train, _logits_train = sess.run([train_op, loss_op, logits], feed_dict={X: train_x, Y: train_y})
            _label_train = [np.argmax(i) for i in _logits_train]
            _label_train_y = [np.argmax(i) for i in train_y]
            _accuracy_train = np.mean(np.array(_label_train) == np.array(_label_train_y))
            avg_acc_train += _accuracy_train


        for j in range(total_batch_test):
            test_x = n2[(j) * batch_size: (j + 1) * batch_size, ...]
            test_y = labels_test[(j) * batch_size: (j + 1) * batch_size, :]

            c_test, _logits_test = sess.run([loss_op, logits], feed_dict={X: test_x, Y: test_y})
            _label_test = [np.argmax(i) for i in _logits_test]
            _label_test_y = [np.argmax(i) for i in test_y]
            _accuracy_test = np.mean(np.array(_label_test) == np.array(_label_test_y))
            avg_acc_test += _accuracy_test

        # print the train and test accuracies   
        print("Train acc: %f, Test_acc: %f" % (avg_acc_train/total_batch_train, avg_acc_test/total_batch_test))
    duration = time.time() - start_time
    print('Time elapsed - {} seconds.'.format(duration))
# Out:
# Train acc: 0.575208, Test_acc: 0.626250
# Train acc: 0.725542, Test_acc: 0.741250
# Train acc: 0.796958, Test_acc: 0.781250
# Train acc: 0.821833, Test_acc: 0.785000
# Train acc: 0.835292, Test_acc: 0.793750
# Train acc: 0.845875, Test_acc: 0.798750
# Train acc: 0.854708, Test_acc: 0.797500
# Train acc: 0.859375, Test_acc: 0.808750
# Train acc: 0.863542, Test_acc: 0.801250
# Train acc: 0.867292, Test_acc: 0.818750
# Train acc: 0.869917, Test_acc: 0.821250
# Train acc: 0.869875, Test_acc: 0.820000
# Train acc: 0.873292, Test_acc: 0.831250
# Train acc: 0.872917, Test_acc: 0.825000
# Train acc: 0.876000, Test_acc: 0.827500
# Train acc: 0.877458, Test_acc: 0.835000
# Train acc: 0.878042, Test_acc: 0.820000
# Train acc: 0.880208, Test_acc: 0.825000
# Train acc: 0.881958, Test_acc: 0.822500
# Train acc: 0.882917, Test_acc: 0.825000
# Train acc: 0.883042, Test_acc: 0.832500
# Train acc: 0.885958, Test_acc: 0.833750
# Train acc: 0.885583, Test_acc: 0.833750
# Train acc: 0.886875, Test_acc: 0.828750
# Train acc: 0.886958, Test_acc: 0.825000
# Train acc: 0.888917, Test_acc: 0.832500
# Train acc: 0.889333, Test_acc: 0.840000
# Train acc: 0.889792, Test_acc: 0.836250
# Train acc: 0.890833, Test_acc: 0.836250
# Train acc: 0.890667, Test_acc: 0.836250
# Train acc: 0.891083, Test_acc: 0.835000
# Train acc: 0.889792, Test_acc: 0.833750
# Train acc: 0.892292, Test_acc: 0.840000
# Train acc: 0.892792, Test_acc: 0.833750
# Train acc: 0.891458, Test_acc: 0.835000
# Train acc: 0.891375, Test_acc: 0.837500
# Train acc: 0.891417, Test_acc: 0.833750
# Train acc: 0.894000, Test_acc: 0.840000
# Train acc: 0.893042, Test_acc: 0.831250
# Train acc: 0.892083, Test_acc: 0.838750
# Train acc: 0.892958, Test_acc: 0.838750
# Train acc: 0.893375, Test_acc: 0.836250
# Train acc: 0.893875, Test_acc: 0.835000
# Train acc: 0.895000, Test_acc: 0.828750
# Train acc: 0.895958, Test_acc: 0.831250
# Train acc: 0.894792, Test_acc: 0.831250
# Train acc: 0.894667, Test_acc: 0.827500
# Train acc: 0.894042, Test_acc: 0.835000
# Train acc: 0.894500, Test_acc: 0.833750
# Train acc: 0.895500, Test_acc: 0.832500
# Time elapsed - 14.198785305023193 seconds.
